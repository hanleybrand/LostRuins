# %% [markdown]
# #### references / libraries
#
# https://docs.python.org/3/library/colorsys.html convert rgb to hsl, hsv and back
#
# https://pillow.readthedocs.io/en/stable/reference/Image.html
#
# https://pillow.readthedocs.io/en/stable/reference/ImageColor.html
#
# https://webcolors.readthedocs.io/en/latest/install.html
#
# https://adamspannbauer.github.io/2018/03/02/app-icon-dominant-colors/ (get_dominant_color())
#
#
# __note:__
#
# if saving html from a plot,
# to remove the resize popups on ipyplot tables, regex searches below, replace with ''
#
# `<a href=.*\n.*\n.*</a>`
#
# `<a href=.*\n.*<span class="ipyplot-img-expand"/>\n.*</a>`

# %%
# this turns off future deprecation warnings from ipyplot, change the commenting to undo and re-run
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
#warnings.simplefilter(action='default', category=FutureWarning)

import math
import colorsys

from PIL import Image as Img, ImageColor
import numpy as np
import cv2
import ipyplot
import webcolors

from colour import Color
from color_utils import get_dominant_color

# these are two ordered lists of block names & block textures as PIL Imgs
from ruined import concretes_names, concretes, stones_names, stones, etces, etces_names, roads_names, roads

all_block_names = concretes_names + etces_names + stones_names + roads_names
all_block_imgs = concretes + etces + stones +roads

# %%
def dom_rgb(pil_img: Img, clusters=None, img_size=None, as_list=None, return_comp=None):
    """
    returns tuple(r,g,b) of the dominant color as  of a PIL Img
    the image as a list using color_utils.dominant_color
    pil_img = Img.open('path/to/file.png')
    img_drgb(pil_img)
    [56.2423442, 34.0834233, 70.1234123]
    """
    if not clusters:
        clusters = 3
    if not img_size:
        img_size = (16, 16)
    
    # convert PIL Img to HSV np.array for opencv to call get_dominant_color
    bgr_image = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
    hsv_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2HSV)

    # 
    dc = get_dominant_color(hsv_image, clusters,img_size)
    # create a square showing dominant color of equal size to input image
    dom_color_hsv = np.full(hsv_image.shape, dc, dtype='uint8')
    # convert to bgr color space for display
    dom_color_bgr = cv2.cvtColor(dom_color_hsv, cv2.COLOR_HSV2BGR)
    
    # retun_comp returns a side-by-side comparison img of the original texture vs the dominant color
    if return_comp:
        
        # combine the original image and the dominant color img
        output_image = np.hstack((bgr_image, dom_color_bgr))

        # convert back to RGB from BGR and return PIL Img
        out_im = cv2.cvtColor(output_image,  cv2.COLOR_BGR2RGB)
        return Img.fromarray(out_im, mode="RGB")
    else:
        # convert dom color image to RGB and create a new Pil Img
        out_im = Img.fromarray(cv2.cvtColor(dom_color_bgr,  cv2.COLOR_BGR2RGB))
        # load array of pixels
        px = out_im.load()
        # get the rgb of pixel 0,0
        ci_rgb = px[0, 0]
        return list(ci_rgb) if as_list else ci_rgb

# %%
def rgb_color_dist(rgb1: tuple, rgb2: tuple):
    r1,g1, b1 = rgb1
    r2,g2, b2 = rgb2
    
    diff = math.sqrt((r2 - r1)**2 +  (g2 - g1)**2 +  (b2 - b1)**2) 
    return diff



col1 = dom_rgb(concretes[1])
col2 = dom_rgb(concretes[2])

r1,g1, b1 = col1
r2,g2, b2 = col2
channel_sub_sq = (r2 - r1)**2 +  (g2 - g1)**2 +  (b2 - b1)**2
dist = math.sqrt(channel_sub_sq )


print(dist, rgb_color_dist(dom_rgb(concretes[1]), dom_rgb(concretes[2])))
# Out:
# 166.27687752661222 166.27687752661222

# %%
def rgb_to_hex(rgb, with_hash=None):
    
    der_hex = '%02x%02x%02x' % rgb
    if with_hash:
        der_hex =  f"#{der_hex}"
    return der_hex

def img_hex(pil_img, with_hash=None):
    rgbl = dom_rgb(pil_img)
    da_hex = rgb_to_hex(tuple(dom_rgb(pil_img)))
    if with_hash:
        da_hex =  f"#{da_hex}"
    return da_hex
    
def img_compliment_rgb(pil_img, as_list=None):
    rgbl = dom_rgb(pil_img, as_list=True)
    compliment = [255 - rgbl[0], 255 - rgbl[1], 255 - rgbl[2]]
    return compliment if as_list else tuple(compliment)

rgb_to_hex((108, 80, 134), with_hash=True)
# Out:
# '#6c5086'

# %%
def get_color_ramp(base_hex:str, steps:int):
    c = Color(base_hex)
    cl = Color(hue=c.get_hue(), saturation=c.get_saturation(), luminance=0.70)
    cd = Color(hue=c.get_hue(), saturation=c.get_saturation(), luminance=0.10)
    
    return [color.get_web() for color in cd.range_to(cl, 2)]

black, white = get_color_ramp('#6c5086', 2)

black
# Out:
# '#1a1320'

# %%
# concrete_dict = { n: {f"{n}.png" : i }  for n, i in dict(zip(concretes_names, concretes)).items()}



info_dict_blocks, img_dict_blocks = ({},{})

for n, i in dict(zip(all_block_names, all_block_imgs)).items():
    domn_rgb = dom_rgb(i)
    compl_rgb = img_compliment_rgb(i)
    dom_hex = rgb_to_hex(domn_rgb)
    c_hex = rgb_to_hex(compl_rgb)
    
    compl_block = {'dist': 1000.0, 'name' : 'bad_distance'}
    
    #print(f"\n====distances from {n}{domn_rgb}'s complimentary rgb {compl_rgb}")
    for n2, i2 in dict(zip(all_block_names, all_block_imgs)).items():
        this_dist = rgb_color_dist(compl_rgb, dom_rgb(i2))
        #print(f"\t{this_dist} -- {n2}")
        if this_dist < compl_block['dist']:
            compl_block = {'dist': this_dist, 'name' : n2}
    
    img_dict_blocks[n] = {
        'texture': i,
        'color_chip' : Img.new('RGB', (16, 16), domn_rgb),
        'comp_img': dom_rgb(i, return_comp=True)
    }
            
    info_dict_blocks[n] = {
        "hex": dom_hex,
        "rgb": domn_rgb,
        "compl_rgb": compl_rgb,
        "compl_block": compl_block["name"],
        "compl_dist": compl_block["dist"]
    }

# %%
#print(len(info_dict_blocks), len(concretes_names + etces_names + stones_names))

ordered_block_info_keys = list(info_dict_blocks.keys())
ordered_block_info_keys.sort()
ordered_block_info = {i: info_dict_blocks[i] for i in ordered_block_info_keys}
 
print(ordered_block_info)
# Out:
# {'andesite': {'hex': '595d54', 'rgb': (89, 93, 84), 'compl_rgb': (166, 162, 171), 'compl_block': 'beige_tile', 'compl_dist': 20.639767440550294}, 'asphalt': {'hex': '515151', 'rgb': (81, 81, 81), 'compl_rgb': (174, 174, 174), 'compl_block': 'beige_tile', 'compl_dist': 23.430749027719962}, 'asphalt_darker': {'hex': '404040', 'rgb': (64, 64, 64), 'compl_rgb': (191, 191, 191), 'compl_block': 'white_concrete', 'compl_dist': 5.196152422706632}, 'beige_tile': {'hex': 'ada698', 'rgb': (173
, 173), 'compl_block': 'light_gray_concrete', 'compl_dist': 53.094255809833136}, 'sandstone': {'hex': '9c9382', 'rgb': (156, 147, 130), 'compl_rgb': (99, 108, 125), 'compl_block': 'cobblestone', 'compl_dist': 28.30194339616981}, 'smooth_basalt': {'hex': '303235', 'rgb': (48, 50, 53), 'compl_rgb': (207, 205, 202), 'compl_block': 'white_granite', 'compl_dist': 3.7416573867739413}, 'smooth_stone': {'hex': '878880', 'rgb': (135, 136, 128), 'compl_rgb': (120, 119, 127), 'compl_block': 'cobblestone', 'compl_dist': 13.379088160259652}, 'tile_irregular': {'hex': '43464b', 'rgb': (67, 70, 75), 'compl_rgb': (188, 185, 180), 'compl_block': 'diorite', 'compl_dist': 8.306623862918075}, 'tile_pattern': {'hex': '453931',  ...

# %%
concretes_names
# Out:
# ['brown_concrete',
#  'gray_concrete',
#  'white_concrete',
#  'light_gray_concrete',
#  'black_concrete']

# %%
c_comps, c_names  = ([],[])


for nm, c in dict(zip(concretes_names + etces_names + stones_names  , concretes + etces + stones )).items():

    ci = dom_rgb(c, return_comp=True)
    px = ci.load()
    ci_rgb = px[17, 0]
    c_comps.append(ci)
    c_names.append(f"{nm}<br>rgb{ci_rgb}<br>{rgb_to_hex(ci_rgb)}")

ipyplot.plot_class_representations(c_comps, c_names)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Aj8ExNrNXr2ogPWGAXDrJV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Aj8ExNrNXr2ogPWGAXDrJV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Aj8ExNrNXr2ogPWGAXDrJV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Aj8ExNrNXr2ogPWGAXDrJV:checked ~ #ipyplot-html-viewer-textarea-Aj8ExNrNXr2ogPWGAXDrJV {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Aj8ExNrNXr2ogPWGAXDrJV:checked + #ipyplot-html-viewer-label-Aj8ExNrNXr2ogPWGAXDrJV:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Aj8ExNrNXr2ogPWGAXDrJV">
#         <label id="ipyplot-html-viewer-label-Aj8ExNrNXr2ogPWGAXDrJV" for="ipyplot-html-viewer-toggle-Aj8ExNrNXr2ogPWGAXDrJV">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Aj8ExNrNXr2ogPWGAXDrJV" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-NZBc9aWjBaeeqmwmqWj2gT {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-NZBc9aWjBaeeqmwmqWj2gT {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-NZBc9aWjBaeeqmwmqWj2gT">
#     <div class="ipyplot-placeholder-div-NZBc9aWjBaeeqmwmqWj2gT">
#         <div id="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-8fHfkqRpLqmGmVtRz9vVPH" class="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">andesite<br>rgb(89, 93, 84)<br>595d54</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-8fHfkqRpLqmGmVtRz9vVPH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NZBc9aWjBaeeqmwmqWj2gT">
#         <div id="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-TjezX3jBVpNeBz4N7b74t8" class="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">basalt_side<br>rgb(58, 60, 64)<br>3a3c40</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-TjezX3jBVpNeBz4N7b74t8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NZBc9aWjBaeeqmwmqWj2gT">
#         <div id="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-FaAi22onB9qmaioCA34tEQ" class="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">basalt_top<br>rgb(50, 51, 55)<br>323337</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-FaAi22onB9qmaioCA34tEQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NZBc9aWjBaeeqmwmqWj2gT">
#         <div id="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-L87N2vzxfTkUjy7cpw4CrV" class="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">black_concrete<br>rgb(67, 64, 64)<br>434040</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-L87N2vzxfTkUjy7cpw4CrV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NZBc9aWjBaeeqmwmqWj2gT">
#         <div id="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-W99NxUYLyxBPBzofPPsi3e" class="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">blackstone<br>rgb(52, 52, 60)<br>34343c</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-W99NxUYLyxBPBzofPPsi3e">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NZBc9aWjBaeeqmwmqWj2gT">
#         <div id="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-GwKdgvfv9ifKss6JBhTir8" class="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">blackstone_top<br>rgb(52, 52, 60)<br>34343c</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-GwKdgvfv9ifKss6JBhTir8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NZBc9aWjBaeeqmwmqWj2gT">
#         <div id="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT-HTr7dvKSyKLEWxVdPee29C" class="ipyplot-content-div-NZBc9aWjBaeeqmwmqWj2gT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">blue_concrete<br>rgb(85, 94, 151)<br>555e97</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NZBc9aWjBaeeqm
class="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">basalt_top</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-aLGM6sAuAZNxX35iHdcxpm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7A
#         <style>
#         #ipyplot-imgs-container-div-DWA87KwcfAMsxJ7Fk7AyGQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7AyGQ {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#     <div class="ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#         <div id="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-oXEnt2uUxALiu4QrKA3noG" class="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">smooth_stone</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-oXEnt2uUxALiu4QrKA3noG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#         <div id="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-izG853RuGuTjeVLjYxX85J" class="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">red_sandstone_top</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-izG853RuGuTjeVLjYxX85J">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#         <div id="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-cM2aGiKqpAQeU9TLzLVt9s" class="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dripstone_block</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-cM2aGiKqpAQeU9TLzLVt9s">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#         <div id="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-H7tYfddehBQM3BHkS4c35V" class="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">smooth_stone_slab_side</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-H7tYfddehBQM3BHkS4c35V">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#         <div id="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-EM4GpP53MNnsvjCL6LZG3d" class="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">sandstone</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-EM4GpP53MNnsvjCL6LZG3d">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#         <div id="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-DLr6bG8EqPV4UzVJ8KsrBr" class="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deepslate</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-DLr6bG8EqPV4UzVJ8KsrBr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#         <div id="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-aLGM6sAuAZNxX35iHdcxpm" class="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">basalt_top</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-aLGM6sAuAZNxX35iHdcxpm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#         <div id="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-BT2FBS3ghpwEMo7xcMeReB" class="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">tuff</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-BT2FBS3ghpwEMo7xcMeReB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#         <div id="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-dk5s2mnWtBksuqnVByZ72u" class="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">diorite</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-dk5s2mnWtBksuqnVByZ72u">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#         <div id="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ-FXpDuHK3i3zr2nuU3sbZXc" class="ipyplot-content-div-DWA87KwcfAMsxJ7Fk7AyGQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deepslate_top</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>

# %%
s_comps, s_names  = ([],[])


for snm, s in dict(zip(stones_names, stones )).items():

    si = dom_rgb(s, return_comp=True)
    px = si.load()
    si_rgb = px[17, 0]
    s_comps.append(si)
    s_names.append(f"{snm}<br>rgb{si_rgb}<br>{rgb_to_hex(si_rgb)}")

ipyplot.plot_images(s_comps, s_names)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Nnmo6XNCkucNrYA4R2Sj2V {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Nnmo6XNCkucNrYA4R2Sj2V {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Nnmo6XNCkucNrYA4R2Sj2V {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Nnmo6XNCkucNrYA4R2Sj2V:checked ~ #ipyplot-html-viewer-textarea-Nnmo6XNCkucNrYA4R2Sj2V {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Nnmo6XNCkucNrYA4R2Sj2V:checked + #ipyplot-html-viewer-label-Nnmo6XNCkucNrYA4R2Sj2V:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Nnmo6XNCkucNrYA4R2Sj2V">
#         <label id="ipyplot-html-viewer-label-Nnmo6XNCkucNrYA4R2Sj2V" for="ipyplot-html-viewer-toggle-Nnmo6XNCkucNrYA4R2Sj2V">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Nnmo6XNCkucNrYA4R2Sj2V" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-VzQTZhpcFxRsk2s75Xeu2K {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-VzQTZhpcFxRsk2s75Xeu2K">
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-X9nRvj8gSskzurdeiB8JbB" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">smooth_stone<br>rgb(135, 136, 128)<br>878880</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-X9nRvj8gSskzurdeiB8JbB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-fTcvLMHMdGCMY7zKktZdv8" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">red_sandstone_top<br>rgb(150, 101, 77)<br>96654d</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-fTcvLMHMdGCMY7zKktZdv8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-ERgGpFxarTb5PKymJr9H3b" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dripstone_block<br>rgb(145, 132, 109)<br>91846d</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-ERgGpFxarTb5PKymJr9H3b">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-DMsuEiwvEKZ5xSmsnegHwh" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">smooth_stone_slab_side<br>rgb(134, 135, 127)<br>86877f</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-DMsuEiwvEKZ5xSmsnegHwh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-WGoBRCgppM6S8mtznCjFM8" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">sandstone<br>rgb(156, 147, 130)<br>9c9382</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-WGoBRCgppM6S8mtznCjFM8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-BkpvLDBUrqkGTtGFo6s7zA" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deepslate<br>rgb(60, 66, 64)<br>3c4240</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-BkpvLDBUrqkGTtGFo6s7zA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-VKteSi5vwvbXMzARbByxxR" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">basalt_top<br>rgb(50, 51, 55)<br>323337</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-c
#         <style>
#         #ipyplot-imgs-container-div-VzQTZhpcFxRsk2s75Xeu2K {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-VzQTZhpcFxRsk2s75Xeu2K">
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-X9nRvj8gSskzurdeiB8JbB" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">smooth_stone<br>rgb(135, 136, 128)<br>878880</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-X9nRvj8gSskzurdeiB8JbB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-fTcvLMHMdGCMY7zKktZdv8" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">red_sandstone_top<br>rgb(150, 101, 77)<br>96654d</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-fTcvLMHMdGCMY7zKktZdv8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-ERgGpFxarTb5PKymJr9H3b" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dripstone_block<br>rgb(145, 132, 109)<br>91846d</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-ERgGpFxarTb5PKymJr9H3b">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-DMsuEiwvEKZ5xSmsnegHwh" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">smooth_stone_slab_side<br>rgb(134, 135, 127)<br>86877f</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-DMsuEiwvEKZ5xSmsnegHwh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-WGoBRCgppM6S8mtznCjFM8" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">sandstone<br>rgb(156, 147, 130)<br>9c9382</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-WGoBRCgppM6S8mtznCjFM8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-BkpvLDBUrqkGTtGFo6s7zA" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deepslate<br>rgb(60, 66, 64)<br>3c4240</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-BkpvLDBUrqkGTtGFo6s7zA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-VKteSi5vwvbXMzARbByxxR" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">basalt_top<br>rgb(50, 51, 55)<br>323337</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-VKteSi5vwvbXMzARbByxxR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-kn5PzGhq5UXG3SLj8FaQgA" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">tuff<br>rgb(181, 158, 136)<br>b59e88</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-kn5PzGhq5UXG3SLj8FaQgA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-8nBGFwhXvr3DXo6qoV6ahF" class="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">diorite<br>rgb(192, 192, 182)<br>c0c0b6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-8nBGFwhXvr3DXo6qoV6ahF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzQTZhpcFxRsk2s75Xeu2K">
#         <div id="ipyplot-content-div-VzQTZhpcFxRsk2s75Xeu2K-EsrSTWtDE

# %%
e_comps, e_names  = ([],[])

for enm, e in dict(zip(etces_names, etces)).items():

    ei = dom_rgb(e, return_comp=True)
    epx = ei.load()
    ei_rgb = epx[17, 0]
    e_comps.append(ei)
    e_names.append(f"{enm}<br>rgb{ei_rgb}<br>{rgb_to_hex(ei_rgb)}")

ipyplot.plot_images(e_comps, e_names)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jEqV9NMpFqsCADcgVGVbwv {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jEqV9NMpFqsCADcgVGVbwv {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jEqV9NMpFqsCADcgVGVbwv {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jEqV9NMpFqsCADcgVGVbwv:checked ~ #ipyplot-html-viewer-textarea-jEqV9NMpFqsCADcgVGVbwv {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jEqV9NMpFqsCADcgVGVbwv:checked + #ipyplot-html-viewer-label-jEqV9NMpFqsCADcgVGVbwv:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-jEqV9NMpFqsCADcgVGVbwv">
#         <label id="ipyplot-html-viewer-label-jEqV9NMpFqsCADcgVGVbwv" for="ipyplot-html-viewer-toggle-jEqV9NMpFqsCADcgVGVbwv">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-jEqV9NMpFqsCADcgVGVbwv" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-9xPP9eWxeacqtepBYNoj4p {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-9xPP9eWxeacqtepBYNoj4p {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-9xPP9eWxeacqtepBYNoj4p {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9xPP9eWxeacqtepBYNoj4p span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-9xPP9eWxeacqtepBYNoj4p span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9xPP9eWxeacqtepBYNoj4p img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-9xPP9eWxeacqtepBYNoj4p span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-9xPP9eWxeacqtepBYNoj4p span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-9xPP9eWxeacqtepBYNoj4p]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-9xPP9eWxeacqtepBYNoj4p]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-9xPP9eWxeacqtepBYNoj4p]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-9xPP9eWxeacqtepBYNoj4p">
#     <div class="ipyplot-placeholder-div-9xPP9eWxeacqtepBYNoj4p">
#         <div id="ipyplot-content-div-9xPP9eWxeacqtepBYNoj4p-2rssc5aQ9pKFqpuEZWN8Kr" class="ipyplot-content-div-9xPP9eWxeacqtepBYNoj4p">
#             <h4 style="font-size: 12px; word-wrap: break-word;
after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-juwriXP5ncyoiJb5gw64wG">
#         <label id="ipyplot-html-viewer-label-juwriXP5ncyoiJb5gw64wG" for="ipyplot-html-viewer-toggle-juwriXP5ncyoiJb5gw64wG">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-juwriXP5ncyoiJb5gw64wG" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-jCpFbVg3La4eRRzdwKGqBw {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jCpFbVg3La4eRRzdwKGqBw">
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-EtGQDbi2XT9GYtnSWsUHBV" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">gray_wood_boards</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-EtGQDbi2XT9GYtnSWsUHBV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-Rn763RZEHdBsRUe3f82DNP" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">tile_irregular</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-Rn763RZEHdBsRUe3f82DNP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-i2iEN9ijoEReP3Kb2rSGZa" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">plastic_blue</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-i2iEN9ijoEReP3Kb2rSGZa">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-oNwn6JsAyZxr6rdV4QC6pv" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">tile_pattern</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-oNwn6JsAyZxr6rdV4QC6pv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-2hek5g22iUsUvp9ZgaHUvd" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_block</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-2hek5g22iUsUvp9ZgaHUvd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-EYqAkTDGJeQoKBbQZ9ynAW" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_pillar</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-EYqAkTDGJeQoKBbQZ9ynAW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-gbrpmdX9oqdD2jkDqLe4Qp" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">gray_wood_planks</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-gbrpmdX9oqdD2jkDqLe4Qp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGq
#         <style>
#         #ipyplot-imgs-container-div-jCpFbVg3La4eRRzdwKGqBw {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jCpFbVg3La4eRRzdwKGqBw">
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-EtGQDbi2XT9GYtnSWsUHBV" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">gray_wood_boards</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-EtGQDbi2XT9GYtnSWsUHBV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-Rn763RZEHdBsRUe3f82DNP" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">tile_irregular</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-Rn763RZEHdBsRUe3f82DNP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-i2iEN9ijoEReP3Kb2rSGZa" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">plastic_blue</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-i2iEN9ijoEReP3Kb2rSGZa">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-oNwn6JsAyZxr6rdV4QC6pv" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">tile_pattern</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-oNwn6JsAyZxr6rdV4QC6pv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-2hek5g22iUsUvp9ZgaHUvd" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_block</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-2hek5g22iUsUvp9ZgaHUvd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-EYqAkTDGJeQoKBbQZ9ynAW" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_pillar</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-EYqAkTDGJeQoKBbQZ9ynAW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-gbrpmdX9oqdD2jkDqLe4Qp" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">gray_wood_planks</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-gbrpmdX9oqdD2jkDqLe4Qp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-ZiGakrq9Qx3tpFHV3VLvvJ" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">blue_tile</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-ZiGakrq9Qx3tpFHV3VLvvJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-m28zsW2uHJiaKh8dJ6qoiD" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bone_tile_2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-m28zsW2uHJiaKh8dJ6qoiD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCpFbVg3La4eRRzdwKGqBw">
#         <div id="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw-bLCSxAWgkjGSHVSSmJseyv" class="ipyplot-content-div-jCpFbVg3La4eRRzdwKGqBw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bone_tile</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>

# %%
## test color conversion there and back again

im = Img.open('blocks_to_ruin/concrete/cyan_concrete.png')

# convert rgb to bgr and then to hsv
bgr_im = cv2.cvtColor(np.array(im), cv2.COLOR_RGB2BGR)
hsv_im = cv2.cvtColor(bgr_im, cv2.COLOR_BGR2HSV)

# get the dom color
dc = get_dominant_color(hsv_im, 3)

# create a comp img between im and a monocolor img from the value of dc
dom_color_hsv = np.full(hsv_im.shape, dc, dtype='uint8')
# convert monocolor img back to bgr
dom_color_bgr = cv2.cvtColor(dom_color_hsv, cv2.COLOR_HSV2BGR)
out_im = cv2.cvtColor(dom_color_bgr,  cv2.COLOR_BGR2RGB)
# print(dc, dom_color_hsv[0] )

# back to RGB
bgr_im2 = cv2.cvtColor(hsv_im, cv2.COLOR_HSV2BGR)
rgb_im2 = cv2.cvtColor(bgr_im, cv2.COLOR_BGR2RGB)
im2 = Img.fromarray(rgb_im2, mode="RGB")

#print(rgb_im2[0], dc)
print('cyan_concrete dominant rgb color')
print(dom_rgb(im, 3), dom_rgb(im, 3, as_list=True ))

ipyplot.plot_images([
    im, im2, dom_rgb(im, return_comp=True)
], ['original', 'converted', 'dom_rgb() comp'])
# Out:
# cyan_concrete dominant rgb color
# (75, 122, 130) [75, 122, 130]
#     <style>
#         #ipyplot-html-viewer-toggle-7ygML4UhDfarkYo8EMPKP4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7ygML4UhDfarkYo8EMPKP4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7ygML4UhDfarkYo8EMPKP4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7ygML4UhDfarkYo8EMPKP4:checked ~ #ipyplot-html-viewer-textarea-7ygML4UhDfarkYo8EMPKP4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7ygML4UhDfarkYo8EMPKP4:checked + #ipyplot-html-viewer-label-7ygML4UhDfarkYo8EMPKP4:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-7ygML4UhDfarkYo8EMPKP4">
#         <label id="ipyplot-html-viewer-label-7ygML4UhDfarkYo8EMPKP4" for="ipyplot-html-viewer-toggle-7ygML4UhDfarkYo8EMPKP4">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-7ygML4UhDfarkYo8EMPKP4" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-JTPm7qzshUQeeLcE6VMJKZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-JTPm7qzshUQeeLcE6VMJKZ {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-JTPm7qzshUQeeLcE6VMJKZ">
#     <div class="ipyplot-placeholder-div-JTPm7qzshUQeeLcE6VMJKZ">
#         <div id="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-KHNuxhk2uSMhEpBtXHqhJL" class="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-KHNuxhk2uSMhEpBtXHqhJL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JTPm7qzshUQeeLcE6VMJKZ">
#         <div id="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-cvLNZaTJkgzVPjTZM4qktG" class="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">converted</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-cvLNZaTJkgzVPjTZM4qktG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JTPm7qzshUQeeLcE6VMJKZ">
#         <div id="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-YS9BtjuhEqriggmTEp42Pq" class="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dom_rgb() comp</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-YS9BtjuhEqriggmTEp42Pq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-JTPm7qzshUQeeLcE6VMJKZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-JTPm7qzshUQeeLcE6VMJKZ {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-JTPm7qzshUQeeLcE6VMJKZ">
#     <div class="ipyplot-placeholder-div-JTPm7qzshUQeeLcE6VMJKZ">
#         <div id="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-KHNuxhk2uSMhEpBtXHqhJL" class="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-KHNuxhk2uSMhEpBtXHqhJL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JTPm7qzshUQeeLcE6VMJKZ">
#         <div id="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-cvLNZaTJkgzVPjTZM4qktG" class="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">converted</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-cvLNZaTJkgzVPjTZM4qktG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JTPm7qzshUQeeLcE6VMJKZ">
#         <div id="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-YS9BtjuhEqriggmTEp42Pq" class="ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dom_rgb() comp</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JTPm7qzshUQeeLcE6VMJKZ-YS9BtjuhEqriggmTEp42Pq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
# for name, info in info_dict_blocks.items():
#     this_compl_rgb = info["compl_rgb"]
    
#     best_distance = {'dist': 1000.0, 'name' : 'bad_distance'}
#     for onm, oinf  in info_dict_blocks.items():
#         other_rgb = oinf['rgb']
#         this_dist = rgb_color_dist(this_compl_rgb, other_rgb)
#         if this_dist < best_distance['dist']:
#             best_distance = {'dist': this_dist, 'name' : onm}
            
#     print(f"{name} {best_distance['name']}'")
#     info_dict_blocks[name]['comp_name'] = best_distance['name']
#     info_dict_blocks[name]['comp_dist'] = best_distance['dist']
#     #print(name, info['rgb'], info["compl_rgb"])

# %%
ipyplot.plot_class_representations(concretes + stones + etces, concretes_names + stones_names + etces_names)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle